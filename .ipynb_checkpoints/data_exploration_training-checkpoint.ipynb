# %% [markdown]
# # Analyse zur Kaufpreissamlung Liegenschaften Wien

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime

import mlflow
import mlflow.sklearn
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score


from flask import Flask, request, jsonify
import requests

# %%
class DataPrep:

    def __init__(self, path):

        self.df = pd.read_parquet(path)

# %%
data_prep = DataPrep("/home/daniel/Dokumente/FH_StPölten/Clean_Coding/CCSE_Repro/data/trainData_20230930/cleaned_data.parquet")

# %%
df = data_prep.df

# %%
import pandas as pd
import folium
import geopandas as gpd
from folium import plugins

# Load Vienna district boundaries GeoJSON data
vienna_districts = gpd.read_file('vienna_districts.geojson')

# Group by postal code and calculate average price
average_prices = df.groupby("PLZ")["Kaufpreis"].mean().reset_index()


# Merge average prices with district data using PLZ as the key
vienna_districts = vienna_districts.merge(average_prices, left_on='PLZ', right_on='PLZ', how='left')

# Create a map centered on Vienna
vienna_map = folium.Map(location=[48.2082, 16.3738], zoom_start=12)

# Add district boundaries to the map
folium.GeoJson(vienna_districts, name='geojson').add_to(vienna_map)

# Add markers for each district with average price as tooltip
for _, row in vienna_districts.iterrows():
    folium.Marker(
        location=[row['geometry'].centroid.y, row['geometry'].centroid.x],  # Use the centroid of the district
        tooltip=f"District: {row['BEZ']}<br>Average Price: €{row['Kaufpreis']:.2f}",
    ).add_to(vienna_map)

# Display the map
vienna_map
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/ogrext.pyx:136, in fiona.ogrext.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: vienna_districts.geojson: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Cell In[35], line 7
#       4 from folium import plugins
#       6 # Load Vienna district boundaries GeoJSON data
# ----> 7 vienna_districts = gpd.read_file('vienna_districts.geojson')
#       9 # Group by postal code and calculate average price
#      10 average_prices = df.groupby("PLZ")["Kaufpreis"].mean().reset_index()
#
# File ~/anaconda3/envs/base_ml/lib/python3.8/site-packages/geopandas/io/file.py:281, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
# ...

# %%
viennese_districts = {
            1010: {"latitude": 48.2092, "longitude": 16.3728},
            1020: {"latitude": 48.2149, "longitude": 16.4083},
            1030: {"latitude": 48.1936, "longitude": 16.3961},
            1040: {"latitude": 48.1921, "longitude": 16.3711},
            1050: {"latitude": 48.1923, "longitude": 16.3585},
            1060: {"latitude": 48.1972, "longitude": 16.3475},
            1070: {"latitude": 48.2025, "longitude": 16.3498},
            1080: {"latitude": 48.2104, "longitude": 16.3472},
            1090: {"latitude": 48.2244, "longitude": 16.3586},
            1100: {"latitude": 48.1526, "longitude": 16.3789},
            1110: {"latitude": 48.1634, "longitude": 16.4407},
            1120: {"latitude": 48.1757, "longitude": 16.3333},
            1130: {"latitude": 48.1787, "longitude": 16.2523},
            1140: {"latitude": 48.2176, "longitude": 16.2331},
            1150: {"latitude": 48.1955, "longitude": 16.3266},
            1160: {"latitude": 48.2137, "longitude": 16.3071},
            1170: {"latitude": 48.2362, "longitude": 16.2827},
            1180: {"latitude": 48.2346, "longitude": 16.3219},
            1190: {"latitude": 48.2511, "longitude": 16.3244},
            1200: {"latitude": 48.2444, "longitude": 16.3858},
            1210: {"latitude": 48.2651, "longitude": 16.4184},
            1220: {"latitude": 48.2163, "longitude": 16.4727},
            1230: {"latitude": 48.1435, "longitude": 16.2935},
        }


# Create a GeoDataFrame from your viennese_districts dictionary
viennese_districts_gdf = gpd.GeoDataFrame(
    data=None,
    geometry=gpd.points_from_xy(
        [v["longitude"] for v in viennese_districts.values()],
        [v["latitude"] for v in viennese_districts.values()]
    ),
    crs="EPSG:4326"  # Assuming WGS 84 projection
)
viennese_districts_gdf.index = viennese_districts.keys()  

data = df

# Group by postal code and calculate average price
average_prices = data.groupby("PLZ")["Kaufpreis"].mean().reset_index()

# Merge the dataframes on the 'PLZ' column
average_prices = average_prices.merge(viennese_districts_gdf, left_on='PLZ', right_on='PLZ', how='left')

# %%
viennese_districts_gdf
# Out:
#                      geometry
# 0   POINT (16.37280 48.20920)
# 1   POINT (16.40830 48.21490)
# 2   POINT (16.39610 48.19360)
# 3   POINT (16.37110 48.19210)
# 4   POINT (16.35850 48.19230)
# 5   POINT (16.34750 48.19720)
# 6   POINT (16.34980 48.20250)
# 7   POINT (16.34720 48.21040)
# 8   POINT (16.35860 48.22440)
# 9   POINT (16.37890 48.15260)
# 10  POINT (16.44070 48.16340)
# 11  POINT (16.33330 48.17570)
# 12  POINT (16.25230 48.17870)
# 13  POINT (16.23310 48.21760)
# 14  POINT (16.32660 48.19550)
# 15  POINT (16.30710 48.21370)
# 16  POINT (16.28270 48.23620)
# 17  POINT (16.32190 48.23460)
# 18  POINT (16.32440 48.25110)
# 19  POINT (16.38580 48.24440)
# 20  POINT (16.41840 48.26510)
# 21  POINT (16.47270 48.21630)
# 22  POINT (16.29350 48.14350)

# %%
import pandas as pd
import folium
from folium import plugins


viennese_districts = {
    1010: {"latitude": 48.2092, "longitude": 16.3728},
    1020: {"latitude": 48.2149, "longitude": 16.4083},
    1030: {"latitude": 48.1936, "longitude": 16.3961},
    1040: {"latitude": 48.1921, "longitude": 16.3711},
    1050: {"latitude": 48.1923, "longitude": 16.3585},
    1060: {"latitude": 48.1972, "longitude": 16.3475},
    1070: {"latitude": 48.2025, "longitude": 16.3498},
    1080: {"latitude": 48.2104, "longitude": 16.3472},
    1090: {"latitude": 48.2244, "longitude": 16.3586},
    1100: {"latitude": 48.1526, "longitude": 16.3789},
    1110: {"latitude": 48.1634, "longitude": 16.4407},
    1120: {"latitude": 48.1757, "longitude": 16.3333},
    1130: {"latitude": 48.1787, "longitude": 16.2523},
    1140: {"latitude": 48.2176, "longitude": 16.2331},
    1150: {"latitude": 48.1955, "longitude": 16.3266},
    1160: {"latitude": 48.2137, "longitude": 16.3071},
    1170: {"latitude": 48.2362, "longitude": 16.2827},
    1180: {"latitude": 48.2346, "longitude": 16.3219},
    1190: {"latitude": 48.2511, "longitude": 16.3244},
    1200: {"latitude": 48.2444, "longitude": 16.3858},
    1210: {"latitude": 48.2651, "longitude": 16.4184},
    1220: {"latitude": 48.2163, "longitude": 16.4727},
    1230: {"latitude": 48.1435, "longitude": 16.2935},
}


# Group by postal code and calculate average price
average_prices = data.groupby("PLZ")["Kaufpreis"].mean().reset_index()

# Merge the dataframes on the 'PLZ' column
average_prices = average_prices.merge(pd.DataFrame.from_dict(viennese_districts, orient='index'), left_on='PLZ', right_index=True)

# Create a map centered on Vienna
vienna_map = folium.Map(location=[48.2082, 16.3738], zoom_start=12)

# Add markers for each postal code with average price as tooltip
for _, row in average_prices.iterrows():
    folium.Marker(
        location=[row["latitude"], row["longitude"]],
        tooltip=f"Postal Code: {row['PLZ']}, Average Price: €{row['Kaufpreis']:.2f}",
    ).add_to(vienna_map)


# # Display the map in Jupyter Notebook
# display(vienna_map)

# # Display the map in Streamlit
# st.title("Average Property Prices in Vienna by Postal Code")
# st.map(vienna_map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# ## Load File

# %%
csv_file = "data/kaufpreissammlung-liegenschaften.csv"

df = pd.read_csv(csv_file,sep=";",encoding="Latin-1",low_memory=False,parse_dates=["Erwerbsdatum", "BJ"])
df = df[["PLZ", "Erwerbsdatum", "zuordnung", "Kaufpreis \x80", "Gst.Fl.", "ErwArt", "% Widmung"]]
# Out:
# /var/folders/08/8s3n2f895zgg2psmtlmnblh80000gn/T/ipykernel_762/2429769699.py:3: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   df = pd.read_csv(csv_file,sep=";",encoding="Latin-1",low_memory=False,parse_dates=["Erwerbsdatum", "BJ"])

# %% [markdown]
# ## Data Preperation / Understanding

# %% [markdown]
# ### Data Understanding

# %%
rename_names =  {
    'zuordnung': 'Liegenschaftstyp',
    'Kaufpreis \x80': 'Kaufpreis',
    'Gst.Fl.': 'Fläche',
    '% Widmung':'Widmung'
    # Fügen Sie weitere Spalten hinzu, die Sie umbenennen möchten
}
df = df.rename(columns=rename_names)

# %%
df.head(5)
# Out:
#       PLZ Erwerbsdatum                 Liegenschaftstyp Kaufpreis   Fläche  \
# 0  1210.0   13.10.2021                    Abbruchobjekt    750000    755.0
# 1  1210.0   13.09.2021  Mietwohnhaus voll/tw. vermietet   1250000    510.0
# 2  1130.0   10.08.2021                    Abbruchobjekt    480000    456.0
# 3  1130.0   30.12.2020                    Abbruchobjekt   1600000    523.0
# 4  1100.0   04.11.2020                         unbebaut  15000000  12768.0
#
#         ErwArt  Widmung
# 0  Kaufvertrag    100.0
# 1  Kaufvertrag    100.0
# 2  Kaufvertrag    100.0
# 3  Kaufvertrag    100.0
# 4  Kaufvertrag     30.0

# %%
df["ErwArt"].unique()
# Out:
# array(['Kaufvertrag', 'Tauschvertrag', 'GRA Beschluss',
#        'Magistratsbeschluss', 'GR Beschluss', 'Versteigerung',
#        'Enteig. /Einl.', 'MA 64-Bescheid', 'Baurechtsvertrag',
#        'KV-Entwurf', 'Sonstiges'], dtype=object)

# %%
df['PLZ'].value_counts()
# Out:
# PLZ
# 1220.0    11813
# 1210.0     7260
# 1230.0     6705
# 1130.0     4066
# 1140.0     3875
# 1100.0     3104
# 1190.0     2804
# 1110.0     2356
# 1170.0     2087
# 1120.0     2071
# 1160.0     1918
# 1020.0     1736
# 1180.0     1437
# 1150.0     1379
# 1030.0     1348
# 1200.0     1053
# 1050.0      986
# 1090.0      938
# 1070.0      869
# 1060.0      640
# 1010.0      488
# 1080.0      483
# 1040.0      457
# 0.0           7
# 1119.0        5
# 1320.0        4
# 1117.0        3
# 1203.0        2
# 1116.0        2
# 1141.0        2
# 1211.0        1
# 5479.0        1
# 1118.0        1
# 1115.0        1
# 1800.0        1
# 1206.0        1
# 1233.0        1
# 100.0         1
# 1880.0        1
# 1022.0        1
# 1179.0        1
# Name: count, dtype: int64

# %%
df['Liegenschaftstyp'].value_counts()
# Out:
# Liegenschaftstyp
# unbebaut                             19755
# Mietwohnhaus voll/tw. vermietet      13643
# Ein-, Zweifamilienhaus               13195
# Abbruchobjekt                         5628
# Betriebsobjekt                        1716
# Kleingarten                           1664
# Sonstiges                             1134
# Büro- u./o. Geschäftsgebäude           963
# Mietwohnhaus leer                      732
# Weingarten                             456
# Landwirtsch. Nutzung                   439
# Villa                                  270
# Büro- u./o. Geschäftsgebäude leer      200
# in Arbeit                              165
# Wald                                    54
# Fabrik                                   2
# Name: count, dtype: int64

# %% [markdown]
# ### Data Prep

# %%
plz_to_drop = [1022, 0, 1880, 1800, 100, 1203, 1233, 1320, 1206, 1119, 1116, 1118, 1117, 1211, 1141, 5479, 1115, 1179]

# Use the isin() method to filter rows where 'PLZ' is not in the list
df = df[~df['PLZ'].isin(plz_to_drop)]

# Convert 'PLZ' to int and drop rows with NaN values in 'PLZ' column
df = df.dropna(subset=['PLZ'])
df['PLZ'] = df['PLZ'].astype(int)

# %%
liegenschaft_to_drop = ["Fabrik", "Wald", "in Arbeit"]
# Use the isin() method to filter rows where 'PLZ' is not in the list
df = df[~df['Liegenschaftstyp'].isin(liegenschaft_to_drop)]

# %%
df = df[df['ErwArt'] == 'Kaufvertrag']
df = df.drop("ErwArt", axis=1)

# %%
df["Kaufpreis"] = pd.to_numeric(df["Kaufpreis"].str.replace(',', '.'), errors='coerce').fillna(0)

# %%
date_format='%d.%m.%Y'
df["Erwerbsdatum"] = pd.to_datetime(df["Erwerbsdatum"], format=date_format, errors='coerce')
df = df[df['Erwerbsdatum'] < pd.to_datetime(datetime.now().date())]

# Drop rows with missing values in specified columns
df = df.dropna()

# %% [markdown]
# ### Check Data

# %% [markdown]
# #### Functions

# %%
def check_nan_in_dataframe(dataframe):
    nan_counts = dataframe.isna().sum()
    print("NaN-Werte in den Spalten des DataFrames:")
    for column, count in nan_counts.items():
        print(f"Spalte '{column}': {count} NaN-Werte")

# %%
def plot_price_trend(df, plz, liegenschaftstyp):
    # Filtern des DataFrames nach der gegebenen PLZ
    analysis_df = df[df["PLZ"] == plz]
    analysis_df = df[df["Liegenschaftstyp"] == liegenschaftstyp]
    
    # Gruppieren nach "Erwerbsdatum" und Durchschnitt der "Preis pro qm2" berechnen
    avg_price_per_year = analysis_df.groupby(analysis_df['Erwerbsdatum'].dt.year)['Preis pro qm2'].mean()

    # Berechnung eines gleitenden 3-Jahres-Durchschnitts (kann angepasst werden)
    rolling_avg = avg_price_per_year.rolling(window=3).mean()

    # Daten aus den Spalten auswählen
    x = avg_price_per_year.index
    y = avg_price_per_year.values
    smoothed_y = rolling_avg.values

    # Diagramm erstellen
    plt.figure(figsize=(10, 6))  # Größe des Diagramms festlegen (optional)
    plt.plot(x, y, marker='o', linestyle='-', label='Preis pro qm2 (Durchschnitt pro Jahr)')
    plt.plot(x, smoothed_y, linestyle='-', linewidth=2, label='Gleitender 3-Jahres-Durchschnitt')
    plt.title(f'Trendanalyse: Preis pro Quadratmeter für PLZ {plz} über die Jahre, für den Liegenschaftstyp: {liegenschaftstyp}')  # Diagrammtitel mit PLZ
    plt.xlabel('Jahr')  # Beschriftung der x-Achse
    plt.ylabel('Preis pro Quadratmeter (in EUR)')  # Beschriftung der y-Achse
    plt.grid(True)  # Gitterlinien hinzufügen (optional)

    # Diagramm anzeigen
    plt.legend()
    plt.tight_layout()  # Platz für Achsenbeschriftungen sicherstellen
    plt.show()  # Diagramm anzeigen

# %% [markdown]
# #### Analyse

# %%
df.head(5)
# Out:
#     PLZ Erwerbsdatum                 Liegenschaftstyp   Kaufpreis   Fläche  \
# 0  1210   2021-10-13                    Abbruchobjekt    750000.0    755.0
# 1  1210   2021-09-13  Mietwohnhaus voll/tw. vermietet   1250000.0    510.0
# 2  1130   2021-08-10                    Abbruchobjekt    480000.0    456.0
# 3  1130   2020-12-30                    Abbruchobjekt   1600000.0    523.0
# 4  1100   2020-11-04                         unbebaut  15000000.0  12768.0
#
#    Widmung
# 0    100.0
# 1    100.0
# 2    100.0
# 3    100.0
# 4     30.0

# %%
check_nan_in_dataframe(df)
# Out:
# NaN-Werte in den Spalten des DataFrames:
# Spalte 'PLZ': 0 NaN-Werte
# Spalte 'Erwerbsdatum': 0 NaN-Werte
# Spalte 'Liegenschaftstyp': 0 NaN-Werte
# Spalte 'Kaufpreis': 0 NaN-Werte
# Spalte 'Fläche': 0 NaN-Werte
# Spalte 'Widmung': 0 NaN-Werte

# %%
analysis_df = df

# %%
analysis_df = df
analysis_df["Preis pro qm2"] = analysis_df["Kaufpreis"]/analysis_df["Fläche"]

# %%
df[df['Erwerbsdatum'] < pd.to_datetime(datetime.now().date())]
# Out:
#         PLZ Erwerbsdatum                 Liegenschaftstyp   Kaufpreis  \
# 0      1210   2021-10-13                    Abbruchobjekt    750000.0
# 1      1210   2021-09-13  Mietwohnhaus voll/tw. vermietet   1250000.0
# 2      1130   2021-08-10                    Abbruchobjekt    480000.0
# 3      1130   2020-12-30                    Abbruchobjekt   1600000.0
# 4      1100   2020-11-04                         unbebaut  15000000.0
# ...     ...          ...                              ...         ...
# 60011  1220   2022-04-05           Ein-, Zweifamilienhaus    630000.0
# 60012  1130   2022-04-27           Ein-, Zweifamilienhaus   1070000.0
# 60013  1220   2022-04-26                         unbebaut  86000000.0
# 60014  1220   2022-04-26                         unbebaut  65000000.0
# 60015  1220   2022-05-09                         unbebaut    315000.0
#
#          Fläche  Widmung  Preis pro qm2
# 0         755.0    100.0     993.377483
# 1         510.0    100.0    2450.980392
# ...

# %%
df["Liegenschaftstyp"].unique()
# Out:
# array(['Abbruchobjekt', 'Mietwohnhaus voll/tw. vermietet', 'unbebaut',
#        'Sonstiges', 'Ein-, Zweifamilienhaus', 'Villa',
#        'Landwirtsch. Nutzung', 'Betriebsobjekt', 'Kleingarten',
#        'Mietwohnhaus leer', 'Weingarten',
#        'Büro- u./o. Geschäftsgebäude leer',
#        'Büro- u./o. Geschäftsgebäude'], dtype=object)

# %%
plot_price_trend(df, 1010, 'Mietwohnhaus voll/tw. vermietet')

# %%
df = df[df['Erwerbsdatum'] >= pd.to_datetime("2000-01-01")]

# %%
# df = df[df['Kaufpreis'] >= 0]

# %%
len(df)
# Out:
# 31521

# %% [markdown]
# # Training

# %%
pre_train_df = df.copy()

# %%
pre_train_df.columns
# Out:
# Index(['PLZ', 'Erwerbsdatum', 'Liegenschaftstyp', 'Kaufpreis', 'Fläche',
#        'Widmung', 'Preis pro qm2'],
#       dtype='object')

# %%
pre_train_df = pre_train_df.drop("Preis pro qm2", axis=1)
pre_train_df = pre_train_df.drop("Widmung", axis=1)

pre_train_df['Liegenschaftstyp_Nummer'] = pre_train_df['Liegenschaftstyp'].astype('category').cat.codes
pre_train_df['Liegenschaftstyp_Nummer'] = pre_train_df['Liegenschaftstyp_Nummer'].astype(int)
num_to_liegenschaft_mapping = pre_train_df[['Liegenschaftstyp_Nummer', 'Liegenschaftstyp']].drop_duplicates()
print(num_to_liegenschaft_mapping)
pre_train_df = pre_train_df.drop("Liegenschaftstyp", axis=1)
# Out:
#        Liegenschaftstyp_Nummer                   Liegenschaftstyp
# 0                            0                      Abbruchobjekt
# 1                            8    Mietwohnhaus voll/tw. vermietet
# 4                           12                           unbebaut
# 5                            9                          Sonstiges
# 7                            4             Ein-, Zweifamilienhaus
# 11                          10                              Villa
# 15                           6               Landwirtsch. Nutzung
# 257                          1                     Betriebsobjekt
# 2589                         5                        Kleingarten
# 10483                        7                  Mietwohnhaus leer
# 15117                       11                         Weingarten
# 22972                        2       Büro- u./o. Geschäftsgebäude
# 23467                        3  Büro- u./o. Geschäftsgebäude leer

# %%
pre_train_df.head(5)
# Out:
#     PLZ Erwerbsdatum   Kaufpreis   Fläche  Liegenschaftstyp_Nummer
# 0  1210   2021-10-13    750000.0    755.0                        0
# 1  1210   2021-09-13   1250000.0    510.0                        8
# 2  1130   2021-08-10    480000.0    456.0                        0
# 3  1130   2020-12-30   1600000.0    523.0                        0
# 4  1100   2020-11-04  15000000.0  12768.0                       12

# %%
type(pre_train_df["Erwerbsdatum"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# Set up an MLflow experiment
mlflow.set_experiment("liegenschaften_firstTry")

# Identify categorical columns (e.g., 'PLZ')
categorical_columns = ['PLZ', 'Liegenschaftstyp_Nummer']  # Replace with the actual name of your categorical column(s)

# Create a ColumnTransformer for one-hot encoding categorical columns
column_transformer = ColumnTransformer(
    transformers=[
        ('onehot', OneHotEncoder(sparse_output=False, drop='first'), categorical_columns)
    ],
    remainder='passthrough'  # Keep numeric columns as-is
)

# Define a list of models and their corresponding hyperparameters
models = [
    ('Linear Regression', LinearRegression(), {}),
    ('Random Forest', RandomForestRegressor(), {'regressor__n_estimators': [50, 100, 200]})
]

# Load your dataset (pre_train_df)
# ...

# Separate the features (X) and target variable (y)
X = pre_train_df.drop(columns=['Erwerbsdatum', 'Kaufpreis'])
y = pre_train_df['Kaufpreis']

# Filter the DataFrame for data points where 'Erwerbsdatum' is greater than '2021-01-01'
test_df = pre_train_df[pre_train_df['Erwerbsdatum'] > '2021-01-01']

# Split the data into training and testing sets based on the 'Erwerbsdatum' filter
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=len(test_df), random_state=42)

# Loop through the list of models, create a pipeline for each, and perform hyperparameter tuning
for model_name, model, param_grid in models:
    with mlflow.start_run():
        # Create a machine learning pipeline
        pipeline = Pipeline([
            ('preprocessor', column_transformer),  # Apply one-hot encoding
            ('regressor', model)  # Use the current model
        ])
        
        # Perform hyperparameter tuning with GridSearchCV
        grid_search = GridSearchCV(pipeline, param_grid, cv=5, scoring='neg_mean_squared_error')
        grid_search.fit(X_train, y_train)
        
        # Get the best hyperparameters from GridSearchCV
        best_params = grid_search.best_params_
        
        # Fit the pipeline with the best hyperparameters to the training data
        best_pipeline = grid_search.best_estimator_
        best_pipeline.fit(X_train, y_train)
        
        # Make predictions on the test set
        y_pred = best_pipeline.predict(X_test)
        
        # Evaluate the model
        mse = mean_squared_error(y_test, y_pred)
        r2 = r2_score(y_test, y_pred)
        
        # Log the model, parameters, and metrics to MLflow
        mlflow.sklearn.log_model(best_pipeline, model_name)
        mlflow.log_params(best_params)  # Log the best hyperparameters
        mlflow.log_metrics({'mse': mse, 'r2': r2})
        
        print(f"Model: {model_name}")
        print(f"Best Hyperparameters: {best_params}")
        print(f"Mean Squared Error: {mse}")
        print(f"R-squared: {r2}")
# Out:
# Model: Linear Regression
# Best Hyperparameters: {}
# Mean Squared Error: 14925262749655.512
# R-squared: 0.24324779959272613
# /home/daniel/anaconda3/envs/base_ml/lib/python3.8/site-packages/_distutils_hack/__init__.py:18: UserWarning: Distutils was imported before Setuptools, but importing Setuptools also replaces the `distutils` module in `sys.modules`. This may lead to undesirable behaviors or errors. To avoid these issues, avoid using distutils directly, ensure that setuptools is installed in the traditional way (e.g. not an editable install), and/or make sure that setuptools is always imported before distutils.
#   warnings.warn(
# /home/daniel/anaconda3/envs/base_ml/lib/python3.8/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# Model: Random Forest
# Best Hyperparameters: {'regressor__n_estimators': 200}
# Mean Squared Error: 14239280946633.594
# ...

# %%
# !!!!!
# Bevor der Code unten ausgeführt werden kann muss erst die Datei app.py ausgeführt werden
# Termnal command: python app.py

# %%
# Define the input data as a Python dictionary
input_data = {
    "PLZ": 1210,
    "Fläche": 755.0,
    "Liegenschaftstyp_Nummer": 0
}

# Define the URL of your prediction endpoint
url = "http://localhost:8001/predict"  # Replace with the actual URL if it's hosted elsewhere

# Send a POST request with the input data as JSON
response = requests.post(url, json=input_data)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    prediction = response.json()["prediction"]
    print(f"Predicted Kaufpreis: {prediction}")
else:
    print(f"Request failed with status code: {response.status_code}")

# %%
import os

# %%
def load_data_from_parquet(path, file_name):
    """
    Load data from a Parquet file.

    Args:
        file_path (str): The path to the directory containing the Parquet file.
        file_name (str): The name of the Parquet file to load.

    Returns:
        pd.DataFrame: The loaded DataFrame.
    """
    try:
        # Construct the full file path
        full_file_path = os.path.join(path, file_name)

        # Load the Parquet file into a DataFrame
        df = pd.read_parquet(full_file_path)

        return df
    except Exception as e:
        print(f"Error loading data from Parquet file: {str(e)}")

# %%
pre_train_df = load_data_from_parquet(path = '/home/daniel/Dokumente/FH_StPölten/Clean_Coding/CCSE_Repro/data/trainData_20230930', file_name = 'cleaned_data.parquet')

# %%
pre_train_df
# Out:
#         PLZ Erwerbsdatum   Kaufpreis    Fläche  Widmung  \
# 0      1210   2021-10-13    750000.0     755.0    100.0
# 1      1210   2021-09-13   1250000.0     510.0    100.0
# 2      1130   2021-08-10    480000.0     456.0    100.0
# 3      1130   2020-12-30   1600000.0     523.0    100.0
# 4      1100   2020-11-04  15000000.0   12768.0     30.0
# ...     ...          ...         ...       ...      ...
# 31516  1220   2022-04-05    630000.0     283.0    100.0
# 31517  1130   2022-04-27   1070000.0     465.0    100.0
# 31518  1220   2022-04-26  86000000.0  258269.0    100.0
# 31519  1220   2022-04-26  65000000.0  258269.0    100.0
# 31520  1220   2022-05-09    315000.0     433.0    100.0
#
#        Liegenschaftstyp_Nummer
# 0                            0
# 1                            8
# 2                            0
# 3                            0
# 4                           12
# ...                        ...
# 31516                        4
# 31517                        4
# ...
